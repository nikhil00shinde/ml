# %%
## DENSE LAYER CLASS

import numpy as np

# Dense Layer
class Layer_Dense:
  # Layer initialization
  def __init__(self, n_inputs, n_neurons):
    # Initialize weights and biases
    self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
    self.biases = np.zeros((1, n_neurons))

  # Forward pass
  def forward(self, inputs):
    # Calculate output values from inputs, weights and biases
    self.output = np.dot(inputs, self.weights) + self.biases


# ReLU activation
class activation_ReLU:
  # Forward pass
  def forward(self, inputs):
    # Calculate output values from input
    self.output = np.maximum(0, inputs)


# Activation Function: Softmax
class Activation_Softmax:
  # Forward pass
  def forward(self, inputs):
    # Get unnormalized probabilities
    exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
    # Normalize them for each sample
    probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
    self.output = probabilities

# %%
# ReLU activation
class Activation_ReLU:
 # Forward pass
 def forward(self, inputs):
 # Calculate output values from input
  self.output = np.maximum(0, inputs)

# %%
# Softmax activation
class Activation_Softmax:
 # Forward pass
 def forward(self, inputs):
 # Get unnormalized probabilities
  exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
 # Normalize them for each sample
  probabilities = exp_values / np.sum(exp_values, axis=1,keepdims=True)
  self.output = probabilities

# %%
# Common loss class
class Loss:
 # Calculates the data and regularization losses
 # given model output and ground truth values
 def calculate(self, output, y):
  # Calculate sample losses
  sample_losses = self.forward(output, y)
  # Calculate mean loss
  data_loss = np.mean(sample_losses)
  # Return loss
  return data_loss

# %%
# Cross-entropy loss
class Loss_CategoricalCrossentropy(Loss):
 # Forward pass
 def forward(self, y_pred, y_true):
  # Number of samples in a batch
  samples = len(y_pred)
  # Clip data to prevent division by 0
  # Clip both sides to not drag mean towards any value
  y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)
  # Probabilities for target values -
  # only if categorical labels
  if len(y_true.shape) == 1:
   correct_confidences = y_pred_clipped[
   range(samples),
   y_true
   ]
  # Mask values - only for one-hot encoded labels
  elif len(y_true.shape) == 2:
   correct_confidences = np.sum(
   y_pred_clipped*y_true,
   axis=1
   )
 # Losses
  negative_log_likelihoods = -np.log(correct_confidences)
  return negative_log_likelihoods

# %%
## The Need For Optimization

# %%
# SIMPLER DATASET
# %pip install nnfs
import matplotlib.pyplot as plt
import nnfs
from nnfs.datasets import vertical_data
nnfs.init()
X, y = vertical_data(samples=100, classes=3)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='brg')
plt.show()
# Out:
# Requirement already satisfied: nnfs in /usr/local/lib/python3.12/dist-packages (0.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nnfs) (2.0.2)

# %%
### STRATEGY 1: RANDOMLY SELECT WEIGHTS AND BIASES - DOES NOT WORK!

# %%
# Create dataset
X, y = vertical_data(samples=100, classes=3)

# Create model
dense1 = Layer_Dense(2,3) # first dense layer, 2 input
activation1 = activation_ReLU()
dense2 = Layer_Dense(3,3) # second dense layer, 3 inputs, 3 outputs
activation2 = Activation_Softmax()

# Create loss function
loss_function = Loss_CategoricalCrossentropy()


# Helper variables
lowest_loss = 9999999 # some initial value
best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()
best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()


for iteration in range(10000):
  # Generate a new set of weights for iteration
  dense1.weights = 0.05 * np.random.randn(2,3)
  dense1.biases = 0.05 * np.random.randn(1,3)
  dense2.weights = 0.05 * np.random.randn(3,3)
  dense2.biases = 0.05 * np.random.randn(1,3)
  # Platform a forward pass of the training data through this layer
  dense1.forward(X)
  activation1.forward(dense1.output)
  dense2.forward(activation1.output)
  activation2.forward(dense2.output)
  # Perform a forward pass through activation function
  # it takes the output of second dense layer here and return loss
  loss = loss_function.calculate(activation2.output, y)
  # Calculate accuracy from output of activation2 and targets
  # calculate values long first axis
  predictions = np.argmax(activation2.output, axis=1)
  accuracy = np.mean(predictions == y)
  if loss < lowest_loss:
    print("New Set of weights found, iteration: ", iteration, 'loss: ', loss, "acc: ", accuracy)
    best_dense1_weights = dense1.weights.copy()
    best_dense1_biases = dense1.biases.copy()
    best_dense2_weights = dense2.weights.copy()
    best_dense2_biases = dense2.biases.copy()
    lowest_loss = loss
# Out:
# New Set of weights found, iteration:  0 loss:  1.1016203 acc:  0.3333333333333333
# New Set of weights found, iteration:  1 loss:  1.1002508 acc:  0.3333333333333333
# New Set of weights found, iteration:  2 loss:  1.0992025 acc:  0.3333333333333333
# New Set of weights found, iteration:  3 loss:  1.0986239 acc:  0.3333333333333333
# New Set of weights found, iteration:  10 loss:  1.0984299 acc:  0.3333333333333333
# New Set of weights found, iteration:  22 loss:  1.0976521 acc:  0.36333333333333334
# New Set of weights found, iteration:  150 loss:  1.0974255 acc:  0.3333333333333333
# New Set of weights found, iteration:  874 loss:  1.0972673 acc:  0.3333333333333333
# New Set of weights found, iteration:  894 loss:  1.096895 acc:  0.3333333333333333
# New Set of weights found, iteration:  1036 loss:  1.0954281 acc:  0.3333333333333333

# %%
# STRATEGY 2: RANDOMLY ADJUST WEIGHTS AND BIASES - WORKS!

# %%
# Create dataset
X, y = vertical_data(samples=100, classes=3)
# Create model
dense1 = Layer_Dense(2, 3) # first dense layer, 2 inputs
activation1 = Activation_ReLU()
dense2 = Layer_Dense(3, 3) # second dense layer, 3 inputs, 3 outputs
activation2 = Activation_Softmax()
# Create loss function
loss_function = Loss_CategoricalCrossentropy()
# Helper variables
lowest_loss = 9999999 # some initial value
best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()
best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()
for iteration in range(10000):
 # Update weights with some small random values
 dense1.weights += 0.05 * np.random.randn(2, 3)
 dense1.biases += 0.05 * np.random.randn(1, 3)
 dense2.weights += 0.05 * np.random.randn(3, 3)
 dense2.biases += 0.05 * np.random.randn(1, 3)
 # Perform a forward pass of our training data through this layer
 dense1.forward(X)
 activation1.forward(dense1.output)
 dense2.forward(activation1.output)
 activation2.forward(dense2.output)
 # Perform a forward pass through activation function
 # it takes the output of second dense layer here and returns loss
 loss = loss_function.calculate(activation2.output, y)
 # Calculate accuracy from output of activation2 and targets
 # calculate values along first axis
 predictions = np.argmax(activation2.output, axis=1)
 accuracy = np.mean(predictions == y)
 # If loss is smaller - print and save weights and biases aside
 if loss < lowest_loss:
  print('New set of weights found, iteration:', iteration,'loss:', loss, 'acc:', accuracy)
  best_dense1_weights = dense1.weights.copy()
  best_dense1_biases = dense1.biases.copy()
  best_dense2_weights = dense2.weights.copy()
  best_dense2_biases = dense2.biases.copy()
  lowest_loss = loss
 # Revert weights and biases
 else:
  dense1.weights = best_dense1_weights.copy()
  dense1.biases = best_dense1_biases.copy()
  dense2.weights = best_dense2_weights.copy()
  dense2.biases = best_dense2_biases.copy()
# Out:
# New set of weights found, iteration: 0 loss: 1.0988653 acc: 0.3333333333333333
# New set of weights found, iteration: 1 loss: 1.0986828 acc: 0.3333333333333333
# New set of weights found, iteration: 10 loss: 1.0986542 acc: 0.3333333333333333
# New set of weights found, iteration: 63 loss: 1.0985402 acc: 0.3333333333333333
# New set of weights found, iteration: 78 loss: 1.0973047 acc: 0.3333333333333333
# New set of weights found, iteration: 92 loss: 1.0969805 acc: 0.61
# New set of weights found, iteration: 93 loss: 1.0948336 acc: 0.3333333333333333
# New set of weights found, iteration: 99 loss: 1.0897939 acc: 0.3333333333333333
# New set of weights found, iteration: 105 loss: 1.0866613 acc: 0.3333333333333333
# New set of weights found, iteration: 107 loss: 1.0851638 acc: 0.3333333333333333
# New set of weights found, iteration: 112 loss: 1.0838935 acc: 0.3333333333333333
# New set of weights found, iteration: 115 loss: 1.0819703 acc: 0.4
# New set of weights found, iteration: 118 loss: 1.0807186 acc: 0.3333333333333333
# New set of weights found, iteration: 120 loss: 1.079541 acc: 0.3466666666666667
# New set of weights found, iteration: 121 loss: 1.0723876 acc: 0.54
# New set of weights found, iteration: 132 loss: 1.0687349 acc: 0.43
# New set of weights found, iteration: 133 loss: 1.0662953 acc: 0.6433333333333333
# New set of weights found, iteration: 135 loss: 1.0658984 acc: 0.6666666666666666
# New set of weights found, iteration: 136 loss: 1.0636599 acc: 0.3333333333333333
# New set of weights found, iteration: 137 loss: 1.0623293 acc: 0.3333333333333333
# New set of weights found, iteration: 139 loss: 1.0554786 acc: 0.65
# New set of weights found, iteration: 140 loss: 1.0542496 acc: 0.6666666666666666
# New set of weights found, iteration: 142 loss: 1.0501139 acc: 0.5966666666666667
# New set of weights found, iteration: 146 loss: 1.0467602 acc: 0.6433333333333333
# New set of weights found, iteration: 147 loss: 1.042829 acc: 0.6366666666666667
# New set of weights found, iteration: 149 loss: 1.0410243 acc: 0.41333333333333333
# New set of weights found, iteration: 152 loss: 1.0296795 acc: 0.5233333333333333
# New set of weights found, iteration: 153 loss: 1.0254328 acc: 0.6566666666666666
# New set of weights found, iteration: 155 loss: 1.0164107 acc: 0.63
# New set of weights found, iteration: 160 loss: 1.0123564 acc: 0.6566666666666666
# New set of weights found, iteration: 163 loss: 1.0086362 acc: 0.6666666666666666
# New set of weights found, iteration: 164 loss: 0.9945686 acc: 0.57
# New set of weights found, iteration: 165 loss: 0.98234445 acc: 0.6566666666666666
# New set of weights found, iteration: 176 loss: 0.9804611 acc: 0.6266666666666667
# New set of weights found, iteration: 184 loss: 0.9745398 acc: 0.6466666666666666
# New set of weights found, iteration: 189 loss: 0.96786416 acc: 0.6566666666666666
# New set of weights found, iteration: 190 loss: 0.95549345 acc: 0.6666666666666666
# New set of weights found, iteration: 195 loss: 0.9538796 acc: 0.6666666666666666
# New set of weights found, iteration: 201 loss: 0.9489925 acc: 0.6133333333333333
# New set of weights found, iteration: 203 loss: 0.94849974 acc: 0.5466666666666666
# New set of weights found, iteration: 204 loss: 0.9447394 acc: 0.6
# New set of weights found, iteration: 206 loss: 0.94106895 acc: 0.6266666666666667
# New set of weights found, iteration: 210 loss: 0.92215353 acc: 0.65
# New set of weights found, iteration: 221 loss: 0.91856676 acc: 0.65
# New set of weights found, iteration: 222 loss: 0.9162327 acc: 0.6466666666666666
# New set of weights found, iteration: 227 loss: 0.9138793 acc: 0.65
# New set of weights found, iteration: 228 loss: 0.89696115 acc: 0.65
# New set of weights found, iteration: 230 loss: 0.8896191 acc: 0.6466666666666666
# New set of weights found, iteration: 232 loss: 0.88831544 acc: 0.6633333333333333
# New set of weights found, iteration: 236 loss: 0.8834727 acc: 0.7966666666666666
# New set of weights found, iteration: 238 loss: 0.881014 acc: 0.73
# New set of weights found, iteration: 240 loss: 0.8790554 acc: 0.8866666666666667
# New set of weights found, iteration: 241 loss: 0.87080956 acc: 0.7233333333333334
# New set of weights found, iteration: 242 loss: 0.8649911 acc: 0.66
# New set of weights found, iteration: 246 loss: 0.86109406 acc: 0.6666666666666666
# New set of weights found, iteration: 247 loss: 0.8439391 acc: 0.7166666666666667
# New set of weights found, iteration: 259 loss: 0.83630747 acc: 0.6633333333333333
# New set of weights found, iteration: 262 loss: 0.830926 acc: 0.66
# New set of weights found, iteration: 263 loss: 0.82118034 acc: 0.7666666666666667
# New set of weights found, iteration: 266 loss: 0.814162 acc: 0.6666666666666666
# New set of weights found, iteration: 268 loss: 0.8091311 acc: 0.6666666666666666
# New set of weights found, iteration: 272 loss: 0.8065652 acc: 0.6666666666666666
# New set of weights found, iteration: 273 loss: 0.80181706 acc: 0.6566666666666666
# New set of weights found, iteration: 274 loss: 0.80003697 acc: 0.66
# New set of weights found, iteration: 276 loss: 0.78454226 acc: 0.6566666666666666
# New set of weights found, iteration: 277 loss: 0.7790466 acc: 0.66
# New set of weights found, iteration: 281 loss: 0.7723152 acc: 0.66
# New set of weights found, iteration: 282 loss: 0.7648452 acc: 0.6666666666666666
# New set of weights found, iteration: 289 loss: 0.761613 acc: 0.66
# New set of weights found, iteration: 291 loss: 0.7432127 acc: 0.66
# New set of weights found, iteration: 293 loss: 0.7317033 acc: 0.73
# New set of weights found, iteration: 294 loss: 0.7285309 acc: 0.7666666666666667
# New set of weights found, iteration: 296 loss: 0.72622913 acc: 0.79
# New set of weights found, iteration: 300 loss: 0.7260699 acc: 0.82
# New set of weights found, iteration: 303 loss: 0.71832454 acc: 0.7433333333333333
# New set of weights found, iteration: 306 loss: 0.71770304 acc: 0.8033333333333333
# New set of weights found, iteration: 307 loss: 0.7044478 acc: 0.79
# New set of weights found, iteration: 314 loss: 0.7036797 acc: 0.79
# New set of weights found, iteration: 316 loss: 0.6968683 acc: 0.79
# New set of weights found, iteration: 320 loss: 0.68330884 acc: 0.7233333333333334
# New set of weights found, iteration: 322 loss: 0.6760118 acc: 0.74
# New set of weights found, iteration: 324 loss: 0.6751166 acc: 0.8166666666666667
# New set of weights found, iteration: 325 loss: 0.67215675 acc: 0.83
# New set of weights found, iteration: 330 loss: 0.66388893 acc: 0.8366666666666667
# New set of weights found, iteration: 334 loss: 0.6612612 acc: 0.7666666666666667
# New set of weights found, iteration: 335 loss: 0.659689 acc: 0.72
# New set of weights found, iteration: 336 loss: 0.6455137 acc: 0.7733333333333333
# New set of weights found, iteration: 339 loss: 0.6448463 acc: 0.8033333333333333
# New set of weights found, iteration: 341 loss: 0.6403591 acc: 0.7433333333333333
# New set of weights found, iteration: 342 loss: 0.6377991 acc: 0.7233333333333334
# New set of weights found, iteration: 345 loss: 0.63526 acc: 0.7566666666666667
# New set of weights found, iteration: 346 loss: 0.63036054 acc: 0.7266666666666667
# New set of weights found, iteration: 347 loss: 0.61747444 acc: 0.7766666666666666
# New set of weights found, iteration: 348 loss: 0.6130486 acc: 0.8066666666666666
# New set of weights found, iteration: 363 loss: 0.61205536 acc: 0.8433333333333334
# New set of weights found, iteration: 367 loss: 0.5991631 acc: 0.8233333333333334
# New set of weights found, iteration: 372 loss: 0.5967339 acc: 0.8233333333333334
# New set of weights found, iteration: 375 loss: 0.5965779 acc: 0.8366666666666667
# New set of weights found, iteration: 377 loss: 0.5941034 acc: 0.8466666666666667
# New set of weights found, iteration: 380 loss: 0.58716625 acc: 0.8933333333333333
# New set of weights found, iteration: 385 loss: 0.58512306 acc: 0.85
# New set of weights found, iteration: 387 loss: 0.585061 acc: 0.8533333333333334
# New set of weights found, iteration: 390 loss: 0.57783896 acc: 0.8433333333333334
# New set of weights found, iteration: 394 loss: 0.5662676 acc: 0.88
# New set of weights found, iteration: 400 loss: 0.56500435 acc: 0.9033333333333333
# New set of weights found, iteration: 406 loss: 0.56102335 acc: 0.8333333333333334
# New set of weights found, iteration: 407 loss: 0.5491275 acc: 0.85
# New set of weights found, iteration: 411 loss: 0.5473482 acc: 0.88
# New set of weights found, iteration: 413 loss: 0.54388994 acc: 0.9166666666666666
# New set of weights found, iteration: 421 loss: 0.5437405 acc: 0.9333333333333333
# New set of weights found, iteration: 423 loss: 0.5335343 acc: 0.9233333333333333
# New set of weights found, iteration: 430 loss: 0.5288879 acc: 0.94
# New set of weights found, iteration: 431 loss: 0.52396184 acc: 0.9333333333333333
# New set of weights found, iteration: 432 loss: 0.51179737 acc: 0.9366666666666666
# New set of weights found, iteration: 433 loss: 0.5074577 acc: 0.9366666666666666
# New set of weights found, iteration: 435 loss: 0.49720836 acc: 0.93
# New set of weights found, iteration: 437 loss: 0.49679056 acc: 0.9366666666666666
# New set of weights found, iteration: 438 loss: 0.48763514 acc: 0.8966666666666666
# New set of weights found, iteration: 439 loss: 0.48670477 acc: 0.9366666666666666
# New set of weights found, iteration: 440 loss: 0.47611156 acc: 0.9233333333333333
# New set of weights found, iteration: 451 loss: 0.47018442 acc: 0.9133333333333333
# New set of weights found, iteration: 453 loss: 0.4631221 acc: 0.9233333333333333
# New set of weights found, iteration: 456 loss: 0.45915136 acc: 0.92
# New set of weights found, iteration: 457 loss: 0.4559615 acc: 0.93
# New set of weights found, iteration: 462 loss: 0.44222045 acc: 0.93
# New set of weights found, iteration: 466 loss: 0.4397405 acc: 0.9366666666666666
# New set of weights found, iteration: 469 loss: 0.43100053 acc: 0.94
# New set of weights found, iteration: 477 loss: 0.4271097 acc: 0.9366666666666666
# New set of weights found, iteration: 484 loss: 0.42445886 acc: 0.9366666666666666
# New set of weights found, iteration: 487 loss: 0.4241064 acc: 0.94
# New set of weights found, iteration: 488 loss: 0.4218641 acc: 0.94
# New set of weights found, iteration: 494 loss: 0.42183405 acc: 0.9333333333333333
# New set of weights found, iteration: 495 loss: 0.4207562 acc: 0.9133333333333333
# New set of weights found, iteration: 496 loss: 0.4170294 acc: 0.9033333333333333
# New set of weights found, iteration: 498 loss: 0.41682765 acc: 0.9233333333333333
# New set of weights found, iteration: 503 loss: 0.41047263 acc: 0.94
# New set of weights found, iteration: 525 loss: 0.40414473 acc: 0.9366666666666666
# New set of weights found, iteration: 531 loss: 0.40375727 acc: 0.9333333333333333
# New set of weights found, iteration: 532 loss: 0.40138906 acc: 0.9333333333333333
# New set of weights found, iteration: 535 loss: 0.4012159 acc: 0.9233333333333333
# New set of weights found, iteration: 537 loss: 0.38824362 acc: 0.93
# New set of weights found, iteration: 547 loss: 0.3881573 acc: 0.9333333333333333
# New set of weights found, iteration: 549 loss: 0.38190928 acc: 0.9366666666666666
# New set of weights found, iteration: 551 loss: 0.37740773 acc: 0.9266666666666666
# New set of weights found, iteration: 555 loss: 0.37734318 acc: 0.92
# New set of weights found, iteration: 560 loss: 0.37264088 acc: 0.9333333333333333
# New set of weights found, iteration: 564 loss: 0.37070876 acc: 0.9333333333333333
# New set of weights found, iteration: 565 loss: 0.3650717 acc: 0.9366666666666666
# New set of weights found, iteration: 574 loss: 0.3649638 acc: 0.9266666666666666
# New set of weights found, iteration: 579 loss: 0.36398366 acc: 0.92
# New set of weights found, iteration: 584 loss: 0.3628332 acc: 0.9033333333333333
# New set of weights found, iteration: 587 loss: 0.36065695 acc: 0.9133333333333333
# New set of weights found, iteration: 591 loss: 0.35859054 acc: 0.92
# New set of weights found, iteration: 595 loss: 0.35474268 acc: 0.92
# New set of weights found, iteration: 608 loss: 0.35428903 acc: 0.9233333333333333
# New set of weights found, iteration: 611 loss: 0.35333705 acc: 0.92
# New set of weights found, iteration: 618 loss: 0.3509554 acc: 0.9266666666666666
# New set of weights found, iteration: 623 loss: 0.34754607 acc: 0.93
# New set of weights found, iteration: 629 loss: 0.34506413 acc: 0.93
# New set of weights found, iteration: 630 loss: 0.34127954 acc: 0.93
# New set of weights found, iteration: 631 loss: 0.3326748 acc: 0.92
# New set of weights found, iteration: 636 loss: 0.32853964 acc: 0.9333333333333333
# New set of weights found, iteration: 646 loss: 0.32777798 acc: 0.93
# New set of weights found, iteration: 647 loss: 0.32589772 acc: 0.93
# New set of weights found, iteration: 666 loss: 0.3247119 acc: 0.9233333333333333
# New set of weights found, iteration: 668 loss: 0.3219579 acc: 0.93
# New set of weights found, iteration: 669 loss: 0.3209166 acc: 0.9233333333333333
# New set of weights found, iteration: 674 loss: 0.31778148 acc: 0.93
# New set of weights found, iteration: 677 loss: 0.31172502 acc: 0.9233333333333333
# New set of weights found, iteration: 678 loss: 0.3105199 acc: 0.9166666666666666
# New set of weights found, iteration: 681 loss: 0.30667832 acc: 0.9366666666666666
# New set of weights found, iteration: 684 loss: 0.30351803 acc: 0.9366666666666666
# New set of weights found, iteration: 699 loss: 0.30255032 acc: 0.9366666666666666
# New set of weights found, iteration: 701 loss: 0.3020538 acc: 0.9333333333333333
# New set of weights found, iteration: 708 loss: 0.300439 acc: 0.9333333333333333
# New set of weights found, iteration: 712 loss: 0.29929385 acc: 0.93
# New set of weights found, iteration: 714 loss: 0.2972949 acc: 0.9266666666666666
# New set of weights found, iteration: 724 loss: 0.2969944 acc: 0.9333333333333333
# New set of weights found, iteration: 725 loss: 0.29154766 acc: 0.9266666666666666
# New set of weights found, iteration: 726 loss: 0.29008758 acc: 0.9333333333333333
# New set of weights found, iteration: 727 loss: 0.28726828 acc: 0.9233333333333333
# New set of weights found, iteration: 737 loss: 0.2854745 acc: 0.93
# New set of weights found, iteration: 744 loss: 0.28467152 acc: 0.9333333333333333
# New set of weights found, iteration: 750 loss: 0.28130013 acc: 0.93
# New set of weights found, iteration: 754 loss: 0.27733526 acc: 0.9366666666666666
# New set of weights found, iteration: 761 loss: 0.27671978 acc: 0.94
# New set of weights found, iteration: 763 loss: 0.27334523 acc: 0.9333333333333333
# New set of weights found, iteration: 765 loss: 0.27098432 acc: 0.9333333333333333
# New set of weights found, iteration: 767 loss: 0.26816812 acc: 0.9333333333333333
# New set of weights found, iteration: 772 loss: 0.26706523 acc: 0.9333333333333333
# New set of weights found, iteration: 776 loss: 0.2663999 acc: 0.94
# New set of weights found, iteration: 780 loss: 0.26588744 acc: 0.9333333333333333
# New set of weights found, iteration: 782 loss: 0.26567033 acc: 0.9433333333333334
# New set of weights found, iteration: 785 loss: 0.26296175 acc: 0.9366666666666666
# New set of weights found, iteration: 795 loss: 0.26076263 acc: 0.94
# New set of weights found, iteration: 805 loss: 0.2557283 acc: 0.94
# New set of weights found, iteration: 806 loss: 0.25397432 acc: 0.93
# New set of weights found, iteration: 818 loss: 0.2536206 acc: 0.9333333333333333
# New set of weights found, iteration: 834 loss: 0.25269806 acc: 0.93
# New set of weights found, iteration: 840 loss: 0.24617691 acc: 0.9366666666666666
# New set of weights found, iteration: 842 loss: 0.24498458 acc: 0.93
# New set of weights found, iteration: 845 loss: 0.24433327 acc: 0.9266666666666666
# New set of weights found, iteration: 849 loss: 0.24291499 acc: 0.9366666666666666
# New set of weights found, iteration: 850 loss: 0.24236298 acc: 0.93
# New set of weights found, iteration: 851 loss: 0.24160253 acc: 0.9366666666666666
# New set of weights found, iteration: 854 loss: 0.23829396 acc: 0.9366666666666666
# New set of weights found, iteration: 860 loss: 0.23680572 acc: 0.9333333333333333
# New set of weights found, iteration: 867 loss: 0.23459707 acc: 0.9433333333333334
# New set of weights found, iteration: 868 loss: 0.23112813 acc: 0.9333333333333333
# New set of weights found, iteration: 875 loss: 0.2309314 acc: 0.93
# New set of weights found, iteration: 885 loss: 0.22678037 acc: 0.93
# New set of weights found, iteration: 890 loss: 0.22466177 acc: 0.9333333333333333
# New set of weights found, iteration: 894 loss: 0.22118787 acc: 0.9333333333333333
# New set of weights found, iteration: 907 loss: 0.2196359 acc: 0.9366666666666666
# New set of weights found, iteration: 920 loss: 0.21812434 acc: 0.9333333333333333
# New set of weights found, iteration: 922 loss: 0.21554829 acc: 0.9366666666666666
# New set of weights found, iteration: 927 loss: 0.21491162 acc: 0.9266666666666666
# New set of weights found, iteration: 932 loss: 0.21209271 acc: 0.93
# New set of weights found, iteration: 933 loss: 0.20961729 acc: 0.9366666666666666
# New set of weights found, iteration: 939 loss: 0.20777853 acc: 0.94
# New set of weights found, iteration: 943 loss: 0.20482993 acc: 0.9266666666666666
# New set of weights found, iteration: 963 loss: 0.20391347 acc: 0.93
# New set of weights found, iteration: 980 loss: 0.2004708 acc: 0.9266666666666666
# New set of weights found, iteration: 986 loss: 0.19865575 acc: 0.9333333333333333
# New set of weights found, iteration: 996 loss: 0.19768193 acc: 0.94
# New set of weights found, iteration: 1011 loss: 0.1950502 acc: 0.93
# New set of weights found, iteration: 1026 loss: 0.19406344 acc: 0.9333333333333333
# New set of weights found, iteration: 1029 loss: 0.1935359 acc: 0.94
# New set of weights found, iteration: 1037 loss: 0.19205184 acc: 0.9366666666666666
# New set of weights found, iteration: 1063 loss: 0.1914028 acc: 0.9333333333333333
# New set of weights found, iteration: 1073 loss: 0.18974881 acc: 0.9266666666666666
# New set of weights found, iteration: 1107 loss: 0.18937747 acc: 0.94
# New set of weights found, iteration: 1109 loss: 0.18716076 acc: 0.9366666666666666
# New set of weights found, iteration: 1130 loss: 0.18689914 acc: 0.94
# New set of weights found, iteration: 1152 loss: 0.18581787 acc: 0.9266666666666666
# New set of weights found, iteration: 1170 loss: 0.18536213 acc: 0.9366666666666666
# New set of weights found, iteration: 1177 loss: 0.18532577 acc: 0.9333333333333333
# New set of weights found, iteration: 1200 loss: 0.18332872 acc: 0.9333333333333333
# New set of weights found, iteration: 1211 loss: 0.18176118 acc: 0.93
# New set of weights found, iteration: 1254 loss: 0.18173747 acc: 0.9333333333333333
# New set of weights found, iteration: 1255 loss: 0.18147448 acc: 0.9366666666666666
# New set of weights found, iteration: 1257 loss: 0.18022582 acc: 0.9333333333333333
# New set of weights found, iteration: 1274 loss: 0.18016048 acc: 0.93
# New set of weights found, iteration: 1278 loss: 0.17907406 acc: 0.93
# New set of weights found, iteration: 1283 loss: 0.17685843 acc: 0.9366666666666666
# New set of weights found, iteration: 1304 loss: 0.17503618 acc: 0.9366666666666666
# New set of weights found, iteration: 1326 loss: 0.17495164 acc: 0.9366666666666666
# New set of weights found, iteration: 1346 loss: 0.17395823 acc: 0.9333333333333333
# New set of weights found, iteration: 1361 loss: 0.17348251 acc: 0.93
# New set of weights found, iteration: 1366 loss: 0.17264715 acc: 0.9366666666666666
# New set of weights found, iteration: 1379 loss: 0.17263582 acc: 0.9333333333333333
# New set of weights found, iteration: 1381 loss: 0.16940938 acc: 0.93
# New set of weights found, iteration: 1390 loss: 0.16878055 acc: 0.9333333333333333
# New set of weights found, iteration: 1391 loss: 0.16873601 acc: 0.93
# New set of weights found, iteration: 1392 loss: 0.16844015 acc: 0.9366666666666666
# New set of weights found, iteration: 1405 loss: 0.16711782 acc: 0.9333333333333333
# New set of weights found, iteration: 1412 loss: 0.16679364 acc: 0.9333333333333333
# New set of weights found, iteration: 1449 loss: 0.1663823 acc: 0.9366666666666666
# New set of weights found, iteration: 1458 loss: 0.16488834 acc: 0.9333333333333333
# New set of weights found, iteration: 1459 loss: 0.16409332 acc: 0.9333333333333333
# New set of weights found, iteration: 1462 loss: 0.16329455 acc: 0.9366666666666666
# New set of weights found, iteration: 1470 loss: 0.16289124 acc: 0.93
# New set of weights found, iteration: 1530 loss: 0.16253018 acc: 0.9366666666666666
# New set of weights found, iteration: 1534 loss: 0.16166283 acc: 0.9366666666666666
# New set of weights found, iteration: 1539 loss: 0.16115293 acc: 0.9333333333333333
# New set of weights found, iteration: 1555 loss: 0.16076949 acc: 0.9333333333333333
# New set of weights found, iteration: 1559 loss: 0.15994288 acc: 0.9333333333333333
# New set of weights found, iteration: 1573 loss: 0.15923464 acc: 0.9366666666666666
# New set of weights found, iteration: 1583 loss: 0.15773068 acc: 0.9333333333333333
# New set of weights found, iteration: 1618 loss: 0.15713152 acc: 0.94
# New set of weights found, iteration: 1627 loss: 0.1555834 acc: 0.9333333333333333
# New set of weights found, iteration: 1632 loss: 0.15420741 acc: 0.9266666666666666
# New set of weights found, iteration: 1633 loss: 0.15391847 acc: 0.93
# New set of weights found, iteration: 1647 loss: 0.15358695 acc: 0.94
# New set of weights found, iteration: 1649 loss: 0.15144518 acc: 0.9333333333333333
# New set of weights found, iteration: 1676 loss: 0.15058808 acc: 0.9366666666666666
# New set of weights found, iteration: 1685 loss: 0.14932576 acc: 0.93
# New set of weights found, iteration: 1689 loss: 0.14884357 acc: 0.9366666666666666
# New set of weights found, iteration: 1696 loss: 0.14883074 acc: 0.93
# New set of weights found, iteration: 1697 loss: 0.14823216 acc: 0.9366666666666666
# New set of weights found, iteration: 1714 loss: 0.14796361 acc: 0.9333333333333333
# New set of weights found, iteration: 1718 loss: 0.14741911 acc: 0.9366666666666666
# New set of weights found, iteration: 1737 loss: 0.14716525 acc: 0.9366666666666666
# New set of weights found, iteration: 1770 loss: 0.14658979 acc: 0.9366666666666666
# New set of weights found, iteration: 1783 loss: 0.14555492 acc: 0.9333333333333333
# New set of weights found, iteration: 1792 loss: 0.14537662 acc: 0.9366666666666666
# New set of weights found, iteration: 1806 loss: 0.14522228 acc: 0.9266666666666666
# New set of weights found, iteration: 1826 loss: 0.14462635 acc: 0.9366666666666666
# New set of weights found, iteration: 1866 loss: 0.14451309 acc: 0.93
# New set of weights found, iteration: 1875 loss: 0.14414519 acc: 0.93
# New set of weights found, iteration: 1893 loss: 0.1439591 acc: 0.9333333333333333
# New set of weights found, iteration: 1919 loss: 0.14265406 acc: 0.9333333333333333
# New set of weights found, iteration: 1922 loss: 0.14163499 acc: 0.9366666666666666
# New set of weights found, iteration: 1923 loss: 0.14091288 acc: 0.9366666666666666
# New set of weights found, iteration: 1927 loss: 0.14019951 acc: 0.9366666666666666
# New set of weights found, iteration: 1947 loss: 0.13930827 acc: 0.9333333333333333
# New set of weights found, iteration: 2009 loss: 0.13873452 acc: 0.9333333333333333
# New set of weights found, iteration: 2025 loss: 0.13855746 acc: 0.9333333333333333
# New set of weights found, iteration: 2033 loss: 0.13847981 acc: 0.94
# New set of weights found, iteration: 2038 loss: 0.13705976 acc: 0.93
# New set of weights found, iteration: 2039 loss: 0.13597883 acc: 0.9333333333333333
# New set of weights found, iteration: 2048 loss: 0.1356896 acc: 0.93
# New set of weights found, iteration: 2053 loss: 0.13551526 acc: 0.93
# New set of weights found, iteration: 2063 loss: 0.13538381 acc: 0.9366666666666666
# New set of weights found, iteration: 2082 loss: 0.13439657 acc: 0.9266666666666666
# New set of weights found, iteration: 2109 loss: 0.13379186 acc: 0.9333333333333333
# New set of weights found, iteration: 2115 loss: 0.13374192 acc: 0.9366666666666666
# New set of weights found, iteration: 2130 loss: 0.1336897 acc: 0.9333333333333333
# New set of weights found, iteration: 2158 loss: 0.13334817 acc: 0.9333333333333333
# New set of weights found, iteration: 2172 loss: 0.13320462 acc: 0.9333333333333333
# New set of weights found, iteration: 2195 loss: 0.13249657 acc: 0.93
# New set of weights found, iteration: 2222 loss: 0.13249221 acc: 0.9333333333333333
# New set of weights found, iteration: 2227 loss: 0.13247581 acc: 0.9366666666666666
# New set of weights found, iteration: 2230 loss: 0.13206339 acc: 0.9333333333333333
# New set of weights found, iteration: 2232 loss: 0.13202438 acc: 0.9433333333333334
# New set of weights found, iteration: 2234 loss: 0.13133517 acc: 0.9366666666666666
# New set of weights found, iteration: 2275 loss: 0.13124105 acc: 0.9433333333333334
# New set of weights found, iteration: 2295 loss: 0.13067833 acc: 0.93
# New set of weights found, iteration: 2320 loss: 0.13004811 acc: 0.9333333333333333
# New set of weights found, iteration: 2352 loss: 0.12974681 acc: 0.93
# New set of weights found, iteration: 2497 loss: 0.1296172 acc: 0.94
# New set of weights found, iteration: 2505 loss: 0.12948377 acc: 0.94
# New set of weights found, iteration: 2517 loss: 0.12935145 acc: 0.9333333333333333
# New set of weights found, iteration: 2569 loss: 0.12911415 acc: 0.9366666666666666
# New set of weights found, iteration: 2597 loss: 0.12897357 acc: 0.9366666666666666
# New set of weights found, iteration: 2604 loss: 0.12839614 acc: 0.94
# New set of weights found, iteration: 2607 loss: 0.1281852 acc: 0.94
# New set of weights found, iteration: 2642 loss: 0.12797783 acc: 0.93
# New set of weights found, iteration: 2644 loss: 0.12793057 acc: 0.9333333333333333
# New set of weights found, iteration: 2716 loss: 0.12790407 acc: 0.9333333333333333
# New set of weights found, iteration: 2722 loss: 0.12777549 acc: 0.9333333333333333
# New set of weights found, iteration: 2756 loss: 0.12773362 acc: 0.93
# New set of weights found, iteration: 2791 loss: 0.12767129 acc: 0.9366666666666666
# New set of weights found, iteration: 2798 loss: 0.1270406 acc: 0.9333333333333333
# New set of weights found, iteration: 2896 loss: 0.1270082 acc: 0.9333333333333333
# New set of weights found, iteration: 2915 loss: 0.12687367 acc: 0.9366666666666666
# New set of weights found, iteration: 2943 loss: 0.1267703 acc: 0.9366666666666666
# New set of weights found, iteration: 2982 loss: 0.12666965 acc: 0.9433333333333334
# New set of weights found, iteration: 3001 loss: 0.12622853 acc: 0.94
# New set of weights found, iteration: 3007 loss: 0.12602895 acc: 0.9333333333333333
# New set of weights found, iteration: 3028 loss: 0.12601696 acc: 0.9333333333333333
# New set of weights found, iteration: 3036 loss: 0.12597372 acc: 0.94
# New set of weights found, iteration: 3042 loss: 0.12563619 acc: 0.94
# New set of weights found, iteration: 3048 loss: 0.1254461 acc: 0.9366666666666666
# New set of weights found, iteration: 3074 loss: 0.12536207 acc: 0.94
# New set of weights found, iteration: 3095 loss: 0.12508167 acc: 0.9333333333333333
# New set of weights found, iteration: 3101 loss: 0.12491905 acc: 0.94
# New set of weights found, iteration: 3111 loss: 0.12471059 acc: 0.94
# New set of weights found, iteration: 3132 loss: 0.12436994 acc: 0.94
# New set of weights found, iteration: 3133 loss: 0.124300234 acc: 0.94
# New set of weights found, iteration: 3237 loss: 0.124261945 acc: 0.9433333333333334
# New set of weights found, iteration: 3265 loss: 0.124227144 acc: 0.94
# New set of weights found, iteration: 3387 loss: 0.124197364 acc: 0.94
# New set of weights found, iteration: 3933 loss: 0.12410669 acc: 0.94
# New set of weights found, iteration: 3949 loss: 0.12407425 acc: 0.94
# New set of weights found, iteration: 3997 loss: 0.12399776 acc: 0.94
# New set of weights found, iteration: 4266 loss: 0.123851635 acc: 0.94
# New set of weights found, iteration: 4431 loss: 0.1236955 acc: 0.94
# New set of weights found, iteration: 5736 loss: 0.12366878 acc: 0.94
# New set of weights found, iteration: 6205 loss: 0.1236022 acc: 0.94
# New set of weights found, iteration: 6240 loss: 0.12356603 acc: 0.94
# New set of weights found, iteration: 6269 loss: 0.12349548 acc: 0.94
# New set of weights found, iteration: 6384 loss: 0.12345476 acc: 0.94
# New set of weights found, iteration: 6389 loss: 0.12343974 acc: 0.94
# New set of weights found, iteration: 6451 loss: 0.123421036 acc: 0.94
# New set of weights found, iteration: 6513 loss: 0.123199105 acc: 0.94
# New set of weights found, iteration: 6531 loss: 0.123040594 acc: 0.94
# New set of weights found, iteration: 7013 loss: 0.12294066 acc: 0.94
# New set of weights found, iteration: 7258 loss: 0.122931495 acc: 0.94
# New set of weights found, iteration: 7385 loss: 0.122913 acc: 0.94
# New set of weights found, iteration: 7576 loss: 0.122893676 acc: 0.94
# New set of weights found, iteration: 8051 loss: 0.12279849 acc: 0.94
